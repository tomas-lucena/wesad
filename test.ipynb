# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import requests
from os import path
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px

from Subject import Subject
from Quest import Quest

pio.templates.default = "plotly_white"

# %%
subject = Subject(S='S10')
df_subject = subject.df_subject
df_subject
# Out:
#        bvp_mean  bvp_min  bvp_max     bvp_std  eda_mean   eda_min   eda_max  \
# 0     15.760000    -0.05    85.71   22.506781  0.875798  0.000000  1.434376
# 1    -41.960313  -549.96   228.25  262.775184  1.448448  1.443331  1.452286
# 2     26.305156     0.16   141.30   39.918580  1.452605  1.451006  1.453565
# 3     -5.872031   -63.86    16.31   23.446554  1.451646  1.451006  1.452286
# 4      6.168125   -26.58    21.01   11.090447  1.449088  1.443331  1.452286
# ...         ...      ...      ...         ...       ...       ...       ...
# 6456  10.372031   -32.47    49.89   24.945699  2.393912  2.392313  2.394872
# 6457  13.934844   -34.95    92.68   36.588845  2.405746  2.397430  2.419178
# 6458  24.097344  -109.38   155.75   83.833175  2.422696  2.416619  2.425574
# 6459 -49.343438  -126.63    18.28   43.596131  2.452438  2.412781  2.510004
# 6460  18.727500    11.21    25.65    4.368752  2.547743  2.541986  2.553499
#
#        eda_std  temp_mean  temp_min  ...  acc_1_max  acc_1_std  acc_2_mean  \
# 0     0.629224     382.21    382.21  ...        -26   0.368902     0.00000
# 1     0.003766      30.37     30.37  ...        -26   0.470929     0.03125
# 2     0.001225      30.35     30.35  ...        -26   0.545325     0.00000
# 3     0.000739      30.35     30.35  ...        -25   0.353553     0.03125
# 4     0.003977      30.37     30.37  ...        -25   0.669015     0.21875
# ...        ...        ...       ...  ...        ...        ...         ...
# 6456  0.001225      31.51     31.51  ...          1  13.993086    59.00000
# 6457  0.010046      31.49     31.49  ...        -10  13.780501    33.40625
# 6458  0.004227      31.53     31.53  ...        -12   4.876602     4.00000
# 6459  0.041858      31.51     31.51  ...        -18   2.889776     2.71875
# 6460  0.008141        NaN       NaN  ...        -18   0.512348     3.25000
#
#       acc_2_min  acc_2_max  acc_2_std  acc_3_mean  acc_3_min  acc_3_max  \
# 0             0          0   0.000000    57.65625         57         58
# 1             0          1   0.176777    57.68750         57         58
# 2             0          0   0.000000    57.59375         57         58
# 3            -1          1   0.309461    57.84375         57         58
# 4            -1          1   0.490844    57.75000         57         59
# ...         ...        ...        ...         ...        ...        ...
# 6456         53         82   8.850005     0.53125        -10         20
# 6457          9         77  25.378247    38.75000          5         61
# 6458         -2         10   3.222902    59.25000         53         63
# 6459         -3          5   1.631037    59.93750         57         62
# 6460          3          4   0.447214    60.18750         59         61
#
#       acc_3_std
# 0      0.482559
# 1      0.470929
# 2      0.498991
# 3      0.368902
# 4      0.508001
# ...         ...
# 6456   7.758385
# 6457  20.308905
# 6458   2.462624
# 6459   1.318296
# 6460   0.543906
#
# [6461 rows x 24 columns]

# %%
subject.get_all_protocol()
# Out:
# ['Base', 'TSST', 'Medi 1', 'Fun', 'Medi 2']

# %%
df_subject = subject.search_protocol('TSST')
df_subject
# Out:
#        bvp_mean  bvp_min  bvp_max    bvp_std  eda_mean   eda_min   eda_max  \
# 1965  -1.970312   -72.21    39.86  35.419305  2.794623  2.791745  2.798141
# 1966   9.277344   -61.72    41.09  31.733587  2.793344  2.789186  2.795583
# 1967   3.196719   -80.36    43.50  39.249772  2.789506  2.784069  2.793024
# 1968   0.005469   -79.16    44.00  37.548805  2.789506  2.789186  2.790465
# 1969  -9.583594   -72.65    34.35  37.143762  2.785988  2.784069  2.787907
# ...         ...      ...      ...        ...       ...       ...       ...
# 2660 -15.722188   -75.51    54.43  30.672243  2.289334  2.283577  2.297649
# 2661   3.597187   -55.55    34.23  28.614800  2.289334  2.288694  2.291252
# 2662   5.615781   -58.43    32.62  27.753707  2.286775  2.284856  2.288694
# 2663  -3.218438   -67.55    37.30  30.910438  2.297969  2.283577  2.311720
# 2664  -5.227656   -85.98    71.35  46.731934  2.294770  2.291252  2.297649
#
#        eda_std  temp_mean  temp_min  ...  acc_1_max  acc_1_std  acc_2_mean  \
# 1965  0.002837      34.31     34.31  ...        -59   0.470929   -19.96875
# 1966  0.002837      34.33     34.33  ...        -59   0.470929   -20.00000
# 1967  0.003960      34.31     34.31  ...        -59   0.456803   -20.00000
# 1968  0.000640      34.31     34.31  ...        -59   0.439941   -19.78125
# 1969  0.001652      34.31     34.31  ...        -59   0.504016   -20.00000
# ...        ...        ...       ...  ...        ...        ...         ...
# 2660  0.005955      34.39     34.39  ...        -37   0.000000   -16.71875
# 2661  0.001279      34.37     34.37  ...        -37   0.000000   -16.56250
# 2662  0.001652      34.37     34.37  ...        -36   0.176777   -16.81250
# 2663  0.013911      34.37     34.37  ...        -33   2.756042   -17.90625
# 2664  0.002837      34.37     34.37  ...        -43   0.535061   -19.06250
#
#       acc_2_min  acc_2_max  acc_2_std  acc_3_mean  acc_3_min  acc_3_max  \
# 1965        -20        -19   0.176777    15.96875         15         16
# 1966        -20        -20   0.000000    15.96875         15         16
# 1967        -20        -20   0.000000    16.00000         16         16
# 1968        -20        -19   0.420013    16.00000         16         16
# 1969        -20        -20   0.000000    15.96875         15         16
# ...         ...        ...        ...         ...        ...        ...
# 2660        -17        -16   0.456803    49.00000         49         49
# 2661        -17        -16   0.504016    49.00000         49         49
# 2662        -17        -16   0.396558    49.00000         49         49
# 2663        -20        -16   1.088336    46.12500         42         53
# 2664        -20        -18   0.353553    41.90625         40         43
#
#       acc_3_std
# 1965   0.176777
# 1966   0.176777
# 1967   0.000000
# 1968   0.000000
# 1969   0.176777
# ...         ...
# 2660   0.000000
# 2661   0.000000
# 2662   0.000000
# 2663   3.376866
# 2664   0.530330
#
# [700 rows x 24 columns]

# %%
columns = [col for col in df_subject if ('mean' in col) & ('acc' in col)]

px.line(df_subject[columns])

# %%
columns = [col for col in df_subject if ('mean' in col) & ('eda' in col)]

px.line(df_subject[columns]).show()

# %%
columns = [col for col in df_subject if ('mean' in col) & ('bvp' in col)]

px.line(df_subject[columns]).show()

# %%
columns = [col for col in df_subject if ('mean' in col) & ('eda' in col)]

px.line(df_subject[columns]).show()

# %%
columns = [col for col in df_subject if ('mean' in col) & ('temp' in col)]

px.line(df_subject[columns]).show()
